# %% [markdown]
# # Raw Audios -> wav Audios
# Audio files ori -> Audio files

# %%
import os
import shutil
import re

# 设定原始和目标文件夹的完整路径
src_base_dir = "E:/AMR/DA/Projekt/data/Audio_files_ori"  # 原始文件夹
dst_base_dir = "E:/AMR/DA/Projekt/data/Audio_files"  # 目标文件夹

# 确保目标文件夹存在
os.makedirs(dst_base_dir, exist_ok=True)

# 正则表达式匹配 XC 编号格式，例如 "XC123456"
xc_pattern = re.compile(r"(XC\d+)")

# 遍历原始文件夹
for folder in os.listdir(src_base_dir):
    src_folder_path = os.path.join(src_base_dir, folder)
    dst_folder_path = os.path.join(dst_base_dir, folder)

    # 确保目标子文件夹存在
    os.makedirs(dst_folder_path, exist_ok=True)

    # 确保是文件夹
    if os.path.isdir(src_folder_path):
        for file in os.listdir(src_folder_path):
            if file.endswith((".mp3", ".ogg", ".wav")):  # 处理音频文件
                match = xc_pattern.search(file)  # 提取 XC 编号
                if match:
                    number = match.group(1)  # 只保留 "XC123456"
                    new_filename = f"{number}.wav"  # 统一改为 "XC123456.wav"

                    # 原始文件路径和目标文件路径
                    src_file_path = os.path.join(src_folder_path, file)
                    dst_file_path = os.path.join(dst_folder_path, new_filename)

                    # 复制并重命名
                    shutil.copy2(src_file_path, dst_file_path)
                    print(f"已处理: {src_file_path} -> {dst_file_path}")

print("所有文件已重命名并移动至目标文件夹！")
# Out:
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC106520_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC106520.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC129576_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC129576.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC129577_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC129577.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC132961_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC132961.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC134722_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC134722.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC134725_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC134725.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC187086_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC187086.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC187088_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC187088.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC187089_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC187089.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC246603_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC246603.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC251899_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC251899.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC266423_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC266423.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC290101_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC290101.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC296181_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC296181.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC303217_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC303217.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC309102_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC309102.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC310407_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC310407.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC310408_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC310408.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC348756_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC348756.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC372286_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC372286.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC416488_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC416488.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC424328_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC424328.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC434845_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC434845.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC462329_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC462329.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC554037_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC554037.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC560441_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC560441.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC565612_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC565612.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC585645_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC585645.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC591462_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC591462.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC596036_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC596036.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC632954_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC632954.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC650807_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC650807.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC650808_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC650808.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC673778_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC673778.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC673779_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC673779.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC673781_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC673781.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC729140_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC729140.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC733347_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC733347.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC733348_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC733348.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC736714_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC736714.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC777140_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC777140.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC792500_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC792500.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC809735_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC809735.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC825472_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC825472.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC825473_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC825473.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC864642_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC864642.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC912752_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC912752.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC912753_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC912753.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC912754_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC912754.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Black-headed Gull\XC912755_Chroicocephalus ridibundus.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Black-headed Gull\XC912755.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC106777_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC106777.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC116060_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC116060.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC116072_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC116072.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC161416_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC161416.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC176476_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC176476.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC176479_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC176479.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC176489_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC176489.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC176491_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC176491.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC179581_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC179581.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC263944_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC263944.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC267544_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC267544.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC27165_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC27165.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC360684_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC360684.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC363864_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC363864.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC390768_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC390768.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC454609_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC454609.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC463895_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC463895.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC469660_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC469660.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC474984_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC474984.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC490827_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC490827.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC543318_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC543318.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC543320_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC543320.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC553619_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC553619.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC553620_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC553620.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC553621_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC553621.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC554986_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC554986.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC61893_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC61893.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC627972_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC627972.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC635655_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC635655.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC661966_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC661966.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC711244_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC711244.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC711380_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC711380.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC750281_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC750281.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC786504_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC786504.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC806434_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC806434.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC862941_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC862941.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC862942_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC862942.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC862943_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC862943.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC862944_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC862944.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Canada Goose\XC898189_Branta canadensis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Canada Goose\XC898189.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC495044_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC495044.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC497850_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC497850.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC500630_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC500630.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC500631_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC500631.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC500636_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC500636.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC501446_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC501446.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC506951_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC506951.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC506952_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC506952.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC509838_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC509838.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC509841_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC509841.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC509842_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC509842.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC510546_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC510546.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC510925_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC510925.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511120_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511120.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511940_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511940.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511942_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511942.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511943_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511943.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511944_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511944.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511945_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511945.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511951_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511951.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511970_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511970.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511972_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511972.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511978_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511978.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC511980_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC511980.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC512537_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC512537.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC516262_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC516262.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC516263_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC516263.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC516957_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC516957.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC518419_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC518419.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC518423_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC518423.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC518439_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC518439.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC518443_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC518443.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC595503_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC595503.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC627317_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC627317.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC642008_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC642008.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC673782_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC673782.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC673783_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC673783.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC676098_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC676098.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC684076_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC684076.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC688965_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC688965.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC738471_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC738471.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC741985_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC741985.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC785829_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC785829.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC805953_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC805953.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC805954_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC805954.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC807330_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC807330.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC881570_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC881570.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC955526_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC955526.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC956667_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC956667.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Carrion Crow\XC972710_Corvus corone.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Carrion Crow\XC972710.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC780514 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC780514.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC781878 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC781878.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC782235 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC782235.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC783056 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC783056.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC786475 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC786475.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC791630 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC791630.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC791631 - Amsel - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC791631.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC857700_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC857700.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC861175_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC861175.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC862289_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC862289.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC864280_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC864280.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC871358_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC871358.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC871714_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC871714.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC871717_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC871717.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC871879_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC871879.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC872566_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC872566.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC872567_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC872567.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC876888_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC876888.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC877449_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC877449.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC877614_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC877614.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC878147_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC878147.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC878531_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC878531.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC879696_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC879696.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC879697_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC879697.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC879801_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC879801.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC879894_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC879894.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC880540_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC880540.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC881565_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC881565.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC883876_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC883876.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC889851 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC889851.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC889875 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC889875.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC891027_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC891027.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC891788 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC891788.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC892801 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC892801.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC893365 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC893365.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC893468_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC893468.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC894808_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC894808.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC894810 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC894810.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC896624_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC896624.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC896728_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC896728.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC896771_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC896771.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC896772 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC896772.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC897656 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC897656.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC898413 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC898413.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC898914 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC898914.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC901973_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC901973.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC919083 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC919083.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC919813 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC919813.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC920319 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC920319.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC923613 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC923613.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC931182 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC931182.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC938476 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC938476.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC939151 - Common Blackbird - Turdus merula merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC939151.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC953491 - Common Blackbird - Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC953491.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC956132 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC956132.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC964249_Turdus merula.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC964249.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Blackbird\XC965144 - Common Blackbird - Turdus merula.mp3 -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Blackbird\XC965144.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC329312_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC329312.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC349837_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC349837.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC349838_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC349838.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC349846_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC349846.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC372470_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC372470.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC372472_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC372472.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC403127_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC403127.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC410007_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC410007.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC410008_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC410008.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC411003_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC411003.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC414323_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC414323.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC463558_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC463558.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC464119_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC464119.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC464315_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC464315.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC464317_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC464317.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC464318_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC464318.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC471638_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC471638.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC477972_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC477972.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC484500_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC484500.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC489185_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC489185.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC550293_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC550293.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC560537_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC560537.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC604232_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC604232.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC630184_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC630184.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC636586_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC636586.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC642390_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC642390.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC642449_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC642449.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC667258_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC667258.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC668787_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC668787.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC684061_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC684061.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC686302_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC686302.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC686930_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC686930.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC687914_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC687914.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC696337_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC696337.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC696934_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC696934.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC715586_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC715586.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC729646_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC729646.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC740668_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC740668.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC762179_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC762179.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC762187_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC762187.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC767842_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC767842.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC800618_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC800618.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC812519_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC812519.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC812520_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC812520.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC821534_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC821534.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC822600_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC822600.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC891499_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC891499.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC909663_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC909663.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC917609_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC917609.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Chaffinch\XC917613_Fringilla coelebs.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Chaffinch\XC917613.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC150030_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC150030.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC150031_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC150031.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202463_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202463.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202464_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202464.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202467_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202467.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202471_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202471.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202473_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202473.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202476_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202476.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202477_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202477.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202480_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202480.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Alarm call - Common Kingfisher\XC202482_Alcedo atthis.wav -> E:/AMR/DA/Projekt/data/Audio_files\Alarm call - Common Kingfisher\XC202482.wav
# ...
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC627544_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC627544.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC628924_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC628924.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC630220_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC630220.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC634208_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC634208.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC637720_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC637720.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC643976_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC643976.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC643999_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC643999.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC648495_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC648495.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC649340_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC649340.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC650238_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC650238.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC654784_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC654784.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC659684_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC659684.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC659689_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC659689.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC661270_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC661270.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC662137_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC662137.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC662140_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC662140.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC664792_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC664792.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC669903_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC669903.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC67407_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC67407.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC67408_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC67408.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC684215_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC684215.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC685377_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC685377.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC687546_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC687546.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC708341_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC708341.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC708344_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC708344.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC710927_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC710927.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC711350_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC711350.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC717424_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC717424.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC721905_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC721905.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC722569_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC722569.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC726461_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC726461.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC727057_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC727057.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC728290_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC728290.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC729829_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC729829.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC73008_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC73008.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC731995_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC731995.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC738007_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC738007.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC738642_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC738642.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC738668_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC738668.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC739016_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC739016.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC741367_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC741367.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC744198_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC744198.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC744199_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC744199.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC744201_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC744201.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC750099_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC750099.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC756311_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC756311.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC757028_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC757028.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC757032_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC757032.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC768380_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC768380.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC77425_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC77425.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC77426_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC77426.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC778328_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC778328.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC779744_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC779744.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC784778_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC784778.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC784958_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC784958.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC791455_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC791455.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC792504_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC792504.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC797525_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC797525.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC797833_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC797833.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC797840_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC797840.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC801024_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC801024.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC802694_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC802694.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC804612_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC804612.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC805976_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC805976.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC808698_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC808698.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC808716_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC808716.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC813095_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC813095.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC823720_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC823720.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC82971_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC82971.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC845810_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC845810.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC872689_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC872689.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC880625_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC880625.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC880867_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC880867.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC883769_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC883769.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC891496_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC891496.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC902478_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC902478.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC902479_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC902479.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC904401_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC904401.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC904811_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC904811.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC904812_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC904812.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC907222_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC907222.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC907224_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC907224.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC909033_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC909033.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC911842_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC911842.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC91540_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC91540.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC917068_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC917068.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC930402_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC930402.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC949913_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC949913.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC955541_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC955541.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC956235_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC956235.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC956733_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC956733.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC957105_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC957105.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC961402_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC961402.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC961403_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC961403.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC961404_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC961404.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC976831_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC976831.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC980537_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC980537.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC982888_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC982888.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC983632_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC983632.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC985801_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC985801.wav
# 已处理: E:/AMR/DA/Projekt/data/Audio_files_ori\Song - Stock Dove\XC985802_Columba oenas.wav -> E:/AMR/DA/Projekt/data/Audio_files\Song - Stock Dove\XC985802.wav
# 所有文件已重命名并移动至目标文件夹！

# %%
import os
root_data_path = "E:/AMR/DA/Projekt/data/data_list/0408"
os.makedirs(root_data_path, exist_ok=True)

# %% [markdown]
# # Train meta csv Generator -> train_meta_100.csv

# %%
import os
import pandas as pd

# 设置数据文件夹路径
base_dir = "E:/AMR/DA/Projekt/data/Audio_files"  # 这里可以改成你的实际路径

# 用于存储数据
data = []

# 遍历 Audio_files 文件夹
for folder in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder)
    
    # 只处理文件夹
    if os.path.isdir(folder_path):
        # 解析文件夹名称，获取 vocalization 和 bird_name
        parts = folder.split(" - ")
        if len(parts) != 2:
            print(f"跳过文件夹：{folder}，命名格式不符合预期")
            continue
        
        vocalization, bird_name = parts
        
        # 遍历该类别下的所有音频文件
        for file in os.listdir(folder_path):
            if file.endswith(".wav"):  # 只处理 .wav 文件
                number = file.replace(".wav", "")  # 提取 XC 编号
                full_path = os.path.join(folder_path, file)  # 记录完整路径（绝对路径）
                full_path = full_path.replace("\\", "/")  # 统一路径分隔符
                data.append([bird_name, vocalization, number, full_path])

# 创建 DataFrame
df = pd.DataFrame(data, columns=["bird_name", "vocalization", "number", "path"])

# 保存 CSV
csv_path = f"{root_data_path}/train_meta_100.csv"
df.to_csv(csv_path, index=False, encoding="utf-8")
print(f"CSV 文件已保存至 {csv_path}")
# Out:
# CSV 文件已保存至 E:/AMR/DA/Projekt/data/data_list/0408/train_meta_100.csv

# %% [markdown]
# # 去重， 从train meta csv中删除有重复XC的行

# %%
import pandas as pd

# 📌 你的 CSV 文件路径
csv_path = f"{root_data_path}/train_meta_100.csv"
output_csv_path = f"{root_data_path}/train_meta_100_deduplicated.csv"

# ✅ 读取 CSV
df = pd.read_csv(csv_path)

# ✅ 提取 `XC` 编号
df["XC_ID"] = df["number"].apply(lambda x: x.split("_")[0] if "_" in x else x)

# ✅ **去重（保留第一次出现的 XC_ID）**
df_deduplicated = df.drop_duplicates(subset="XC_ID", keep="first")

# ✅ **删除 `XC_ID` 辅助列**
df_deduplicated = df_deduplicated.drop(columns=["XC_ID"])

# ✅ 保存去重后的 CSV
df_deduplicated.to_csv(output_csv_path, index=False, encoding="utf-8-sig")

print(f"✅ 去重完成！原始数据: {len(df)} 条 → 处理后: {len(df_deduplicated)} 条")
print(f"📄 结果已保存至: {output_csv_path}")
# Out:
# ✅ 去重完成！原始数据: 10654 条 → 处理后: 9710 条
# 📄 结果已保存至: E:/AMR/DA/Projekt/data/data_list/0408/train_meta_100_deduplicated.csv

# %% [markdown]
# # 新版生成spec和mel，512 256的 -> all_data_meta.csv

# %%
import os
import numpy as np
import pandas as pd
import librosa
import cv2
import math
import cupy as cp
from cupyx.scipy import signal as cupy_signal
from tqdm import tqdm

class config:
    SEED = 2024
    DEVICE = 'cpu'
    GENERATE_STFT = False   # ✅ 是否生成 STFT 线性频谱图
    GENERATE_MEL = True    # ✅ 是否生成 mel 频谱图
    OUTPUT_DIR_SPEC = "E:/AMR/DA/Projekt/data/Audio_spec_paperstyle"
    OUTPUT_DIR_MEL = "E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256"
    FS = 48000
    N_FFT = 512
    WIN_SIZE = 512
    WIN_LAP = 384
    MIN_FREQ = 150
    MAX_FREQ = 15000
    SEGMENT_DURATION = 3
    SPEC_SIZE = (512, 256)

# ✅ 创建输出目录（按需）
if config.GENERATE_STFT:
    os.makedirs(config.OUTPUT_DIR_SPEC, exist_ok=True)
if config.GENERATE_MEL:
    os.makedirs(config.OUTPUT_DIR_MEL, exist_ok=True)

csv_path = f"{root_data_path}/train_meta_100_deduplicated.csv"
train_df = pd.read_csv(csv_path)

def oog2spec_via_cupy(audio_data):
    audio_data = cp.array(audio_data)
    mean_signal = cp.nanmean(audio_data)
    audio_data = cp.nan_to_num(audio_data, nan=mean_signal) if cp.isnan(audio_data).mean() < 1 else cp.zeros_like(audio_data)
    frequencies, times, spec_data = cupy_signal.spectrogram(
        audio_data,
        fs=config.FS,
        nfft=config.N_FFT,
        nperseg=config.WIN_SIZE,
        noverlap=config.WIN_LAP,
        window='hann'
    )
    valid_freq = (frequencies >= config.MIN_FREQ) & (frequencies <= config.MAX_FREQ)
    spec_data = spec_data[valid_freq, :]
    spec_data = cp.log10(spec_data + 1e-20)
    spec_data = spec_data - spec_data.min()
    spec_data = spec_data / spec_data.max()
    return spec_data.get()

def audio2mel(audio_data):
    mel_spec = librosa.feature.melspectrogram(
        y=audio_data,
        sr=config.FS,
        n_fft=config.N_FFT,
        hop_length=config.N_FFT - config.WIN_LAP,
        win_length=config.WIN_SIZE,
        window='hann',
        n_mels=config.SPEC_SIZE[1],
        fmin=config.MIN_FREQ,
        fmax=config.MAX_FREQ
    )
    mel_spec = np.log10(mel_spec + 1e-9)
    mel_spec = mel_spec - mel_spec.min()
    mel_spec = mel_spec / mel_spec.max()
    return mel_spec

all_data = []

for i, row in tqdm(train_df.iterrows(), total=len(train_df)):
    file_path = row["path"]
    bird_name = row["bird_name"]
    vocalization = row["vocalization"]
    number = row["number"]

    try:
        audio_data, _ = librosa.load(file_path, sr=config.FS)
    except Exception as e:
        print(f"加载失败: {file_path}, 错误: {e}")
        continue

    total_duration = len(audio_data) / config.FS
    num_segments = math.floor(total_duration / config.SEGMENT_DURATION)

    for seg_idx in range(num_segments):
        start_idx = seg_idx * config.SEGMENT_DURATION * config.FS
        end_idx = start_idx + config.SEGMENT_DURATION * config.FS
        segment_audio = audio_data[start_idx:end_idx]

        spec_filepath, mel_filepath = "", ""

        if config.GENERATE_STFT:
            spec_data = oog2spec_via_cupy(segment_audio)
            spec_data = cv2.resize(spec_data, config.SPEC_SIZE, interpolation=cv2.INTER_AREA)
            spec_filename = f"{number}_seg{seg_idx}.npy"
            spec_filepath = os.path.join(config.OUTPUT_DIR_SPEC, spec_filename)
            np.save(spec_filepath, spec_data.astype(np.float32))

        if config.GENERATE_MEL:
            mel_data = audio2mel(segment_audio)
            mel_data = cv2.resize(mel_data, config.SPEC_SIZE, interpolation=cv2.INTER_AREA)
            mel_filename = f"{number}_seg{seg_idx}_mel.npy"
            mel_filepath = os.path.join(config.OUTPUT_DIR_MEL, mel_filename)
            np.save(mel_filepath, mel_data.astype(np.float32))

        all_data.append([bird_name, vocalization, number, seg_idx, spec_filepath, mel_filepath])

# ✅ 保存元数据
meta_df = pd.DataFrame(all_data, columns=[
    "bird_name", "vocalization", "number", "segment_index", "spec_path", "mel_path"
])
meta_csv_path = f"{root_data_path}/all_data_meta.csv"
meta_df.to_csv(meta_csv_path, index=False, encoding="utf-8")

print(f"✅ 所有音频处理完成！")
if config.GENERATE_STFT:
    print(f"📁 线性频谱图存储于: {config.OUTPUT_DIR_SPEC}")
if config.GENERATE_MEL:
    print(f"📁 Mel 频谱图存储于: {config.OUTPUT_DIR_MEL}")
print(f"📝 元数据 CSV 文件已保存至: {meta_csv_path}")
# Out:
# c:\Users\40920\.conda\envs\testenv\lib\site-packages\cupyx\jit\_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')
#   0%|          | 0/9710 [00:00<?, ?it/s]c:\Users\40920\.conda\envs\testenv\lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
#   4%|▍         | 418/9710 [01:56<29:27,  5.26it/s]  C:\Users\40920\AppData\Local\Temp\ipykernel_144756\3050288624.py:81: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio_data, _ = librosa.load(file_path, sr=config.FS)
# c:\Users\40920\.conda\envs\testenv\lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
#  17%|█▋        | 1686/9710 [09:28<28:07,  4.75it/s]  C:\Users\40920\AppData\Local\Temp\ipykernel_144756\3050288624.py:69: RuntimeWarning: invalid value encountered in divide
#   mel_spec = mel_spec / mel_spec.max()
# 100%|██████████| 9710/9710 [52:28<00:00,  3.08it/s]
# ✅ 所有音频处理完成！
# 📁 Mel 频谱图存储于: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256
# 📝 元数据 CSV 文件已保存至: E:/AMR/DA/Projekt/data/data_list/0408/all_data_meta.csv

# %% [markdown]
# # 整合freefield

# %%
import os
import shutil

# 配置参数
source_dir = "E:/AMR/DA/Projekt/data/freefield1010"  # 原始目录
target_dir = "E:/AMR/DA/Projekt/data/negative_audio"  # 目标目录

# 确保目标目录存在
os.makedirs(target_dir, exist_ok=True)

# 遍历原始目录及其子目录
for root, _, files in os.walk(source_dir):
    for file in files:
        if file.endswith(".wav"):  # 只处理 .wav 文件
            source_file = os.path.join(root, file)  # 源文件路径
            target_file = os.path.join(target_dir, file)  # 目标文件路径

            # 如果目标文件夹中没有这个文件，则复制
            if not os.path.exists(target_file):
                shutil.copy2(source_file, target_file)  # 使用 copy2 保留文件的原始元数据
                print(f"复制 {source_file} 到 {target_file}")
            else:
                print(f"跳过 {file}，目标文件已存在。")

print("音频文件传输完成！")

# %% [markdown]
# # 新版生成负样本spec和mel，并添加到all data meta 中

# %%
import os
import numpy as np
import pandas as pd
import librosa
import cv2
import math
import cupy as cp
from cupyx.scipy import signal as cupy_signal
from tqdm import tqdm

class config:
    SEED = 2024
    DEVICE = 'cpu'
    GENERATE_STFT = False  # ✅ 控制是否生成 STFT 频谱图
    GENERATE_MEL = True    # ✅ 控制是否生成 mel 频谱图
    OUTPUT_DIR_SPEC = "E:/AMR/DA/Projekt/data/Audio_spec_paperstyle"
    OUTPUT_DIR_MEL = "E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256"
    FS = 48000
    N_FFT = 512
    WIN_SIZE = 512
    WIN_LAP = 384
    MIN_FREQ = 150
    MAX_FREQ = 15000
    SEGMENT_DURATION = 3
    SPEC_SIZE = (512, 256)
    MAX_NEGATIVE_SAMPLES = 3000

# ✅ 创建输出目录
if config.GENERATE_STFT:
    os.makedirs(config.OUTPUT_DIR_SPEC, exist_ok=True)
if config.GENERATE_MEL:
    os.makedirs(config.OUTPUT_DIR_MEL, exist_ok=True)

def oog2spec_via_cupy(audio_data):
    if len(audio_data) == 0:
        return None
    audio_data = cp.array(audio_data)
    frequencies, times, spec_data = cupy_signal.spectrogram(
        audio_data,
        fs=config.FS,
        nfft=config.N_FFT,
        nperseg=config.WIN_SIZE,
        noverlap=config.WIN_LAP,
        window='hann'
    )
    valid_freq = (frequencies >= config.MIN_FREQ) & (frequencies <= config.MAX_FREQ)
    spec_data = spec_data[valid_freq, :]
    spec_data = cp.log10(spec_data + 1e-20)
    spec_data = (spec_data - spec_data.min()) / (spec_data.max() - spec_data.min() + 1e-9)
    return spec_data.get()

def audio2mel(audio_data):
    mel_spec = librosa.feature.melspectrogram(
        y=audio_data,
        sr=config.FS,
        n_fft=config.N_FFT,
        hop_length=config.N_FFT - config.WIN_LAP,
        win_length=config.WIN_SIZE,
        window='hann',
        n_mels=config.SPEC_SIZE[1],
        fmin=config.MIN_FREQ,
        fmax=config.MAX_FREQ
    )
    mel_spec = np.log10(mel_spec + 1e-9)
    mel_spec = (mel_spec - mel_spec.min()) / (mel_spec.max() - mel_spec.min() + 1e-9)
    return mel_spec

# === 负样本音频路径
negative_samples_dir = "E:/AMR/DA/Projekt/data/negative_audio"

negative_samples_processed = 0
negative_data = []

for root, _, files in os.walk(negative_samples_dir):
    for file in tqdm(files, desc="🔄 Processing Negative Audio Files"):
        if not file.endswith(".wav"):
            continue

        file_path = os.path.join(root, file)

        try:
            audio_data, _ = librosa.load(file_path, sr=config.FS)
            if len(audio_data) == 0:
                continue
        except Exception as e:
            print(f"❌ 加载失败: {file}, 错误: {e}")
            continue

        total_duration = len(audio_data) / config.FS
        num_segments = math.floor(total_duration / config.SEGMENT_DURATION)

        max_segments = 3  # ✅ 只保留 seg0～2
        for seg_idx in range(min(num_segments, max_segments)):
            start_idx = seg_idx * config.SEGMENT_DURATION * config.FS
            end_idx = start_idx + config.SEGMENT_DURATION * config.FS
            segment_audio = audio_data[int(start_idx):int(end_idx)]

            if len(segment_audio) < config.SEGMENT_DURATION * config.FS:
                pad_len = config.SEGMENT_DURATION * config.FS - len(segment_audio)
                segment_audio = np.pad(segment_audio, (0, pad_len), mode="constant")

            spec_path, mel_path = "", ""

            if config.GENERATE_STFT:
                spec_data = oog2spec_via_cupy(segment_audio)
                if spec_data is None:
                    continue
                spec_data = cv2.resize(spec_data, config.SPEC_SIZE, interpolation=cv2.INTER_AREA)
                spec_filename = f"negative_{file.split('.')[0]}_seg{seg_idx}.npy"
                spec_path = os.path.join(config.OUTPUT_DIR_SPEC, spec_filename)
                np.save(spec_path, spec_data.astype(np.float32))

            if config.GENERATE_MEL:
                mel_data = audio2mel(segment_audio)
                mel_data = cv2.resize(mel_data, config.SPEC_SIZE, interpolation=cv2.INTER_AREA)
                mel_filename = f"negative_{file.split('.')[0]}_seg{seg_idx}_mel.npy"
                mel_path = os.path.join(config.OUTPUT_DIR_MEL, mel_filename)
                np.save(mel_path, mel_data.astype(np.float32))

            negative_data.append([
                "Background Noise", "none",
                f"negative_{file.split('.')[0]}",
                seg_idx, spec_path, mel_path
            ])

            negative_samples_processed += 1
            if negative_samples_processed >= config.MAX_NEGATIVE_SAMPLES:
                print(f"🎯 达到最大负样本数 {config.MAX_NEGATIVE_SAMPLES}，停止处理。")
                break

        if negative_samples_processed >= config.MAX_NEGATIVE_SAMPLES:
            break
    if negative_samples_processed >= config.MAX_NEGATIVE_SAMPLES:
        break

# ✅ 合并 CSV
meta_csv_path = f"{root_data_path}/all_data_meta.csv"
new_meta_csv_path = f"{root_data_path}/all_data_meta_with_negative.csv"

if os.path.exists(meta_csv_path):
    original_df = pd.read_csv(meta_csv_path)
    negative_df = pd.DataFrame(negative_data, columns=["bird_name", "vocalization", "number", "segment_index", "spec_path", "mel_path"])
    combined_df = pd.concat([original_df, negative_df], ignore_index=True)
else:
    print("⚠️ 未找到原始 CSV，仅使用负样本生成新文件。")
    combined_df = pd.DataFrame(negative_data, columns=["bird_name", "vocalization", "number", "segment_index", "spec_path", "mel_path"])

combined_df.to_csv(new_meta_csv_path, index=False, encoding="utf-8-sig")

# ✅ 输出结果
print(f"\n✅ 负样本处理完成，生成样本数：{negative_samples_processed}")
if config.GENERATE_STFT:
    print(f"📁 STFT 频谱图已保存至: {config.OUTPUT_DIR_SPEC}")
if config.GENERATE_MEL:
    print(f"📁 Mel 频谱图已保存至: {config.OUTPUT_DIR_MEL}")
print(f"📝 合并后的元数据 CSV 保存至: {new_meta_csv_path}")
# Out:
# 🔄 Processing Negative Audio Files:   0%|          | 0/7690 [00:00<?, ?it/s]c:\Users\40920\.conda\envs\testenv\lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# 🔄 Processing Negative Audio Files:  13%|█▎        | 999/7690 [00:39<04:27, 25.00it/s]
# 🎯 达到最大负样本数 3000，停止处理。
#
# ✅ 负样本处理完成，生成样本数：3000
# 📁 Mel 频谱图已保存至: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256
# 📝 合并后的元数据 CSV 保存至: E:/AMR/DA/Projekt/data/data_list/0408/all_data_meta_with_negative.csv

# %% [markdown]
# # Spectogram.npy Filter

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm

# 📌 配置路径
data_csv_path = f"{root_data_path}/all_data_meta_with_negative.csv"
clean_data_csv_path = f"{root_data_path}/all_data_meta_clean.csv"
blacklist_path = f"{root_data_path}/blacklist.txt"

# ✅ 控制检测类型
CHECK_SPEC = False   # 是否检测 spec_path（STFT 图）
CHECK_MEL = True     # 是否检测 mel_path（Mel 图）

# ✅ 加载黑名单
def load_blacklist():
    if os.path.exists(blacklist_path):
        with open(blacklist_path, "r") as f:
            return set(line.strip() for line in f.readlines())
    return set()

# ✅ 保存黑名单
def save_blacklist(blacklist):
    with open(blacklist_path, "w") as f:
        for file in sorted(blacklist):
            f.write(file + "\n")
    print(f"✅ 黑名单已更新，共 {len(blacklist)} 个无效文件")

# ✅ 查找无效 npy 文件
def find_invalid_npy_files(df, blacklist):
    invalid_files = set(blacklist)

    print("🔍 开始检查频谱文件有效性 ...")
    for _, row in tqdm(df.iterrows(), total=len(df), desc="扫描无效数据"):
        path_keys = []
        if CHECK_SPEC:
            path_keys.append("spec_path")
        if CHECK_MEL:
            path_keys.append("mel_path")

        for path_key in path_keys:
            file_path = row.get(path_key, "")
            if not isinstance(file_path, str) or file_path.strip() == "":
                continue  # 忽略空路径

            if file_path in invalid_files:
                continue

            if not os.path.exists(file_path):
                print(f"❌ 文件不存在: {file_path}")
                invalid_files.add(file_path)
                continue

            try:
                arr = np.load(file_path)
                if np.isnan(arr).any() or np.isinf(arr).any():
                    print(f"❌ 发现 NaN/Inf: {file_path}")
                    invalid_files.add(file_path)
            except Exception as e:
                print(f"⚠️ 读取失败: {file_path}, 错误: {e}")
                invalid_files.add(file_path)

    return invalid_files

# ✅ 主流程
df = pd.read_csv(data_csv_path)
blacklist = load_blacklist()
invalid_files = find_invalid_npy_files(df, blacklist)
save_blacklist(invalid_files)

# ✅ 构造过滤条件
mask = pd.Series([False] * len(df))
if CHECK_SPEC:
    mask |= df["spec_path"].isin(invalid_files)
if CHECK_MEL:
    mask |= df["mel_path"].isin(invalid_files)

# ✅ 清洗数据并保存
df_clean = df[~mask]
df_clean.to_csv(clean_data_csv_path, index=False, encoding="utf-8")
print(f"\n✅ 已过滤无效数据，生成 {clean_data_csv_path}（保留 {len(df_clean)} 条数据）")
# Out:
# 🔍 开始检查频谱文件有效性 ...
# 扫描无效数据:  18%|█▊        | 32754/187052 [04:06<19:49, 129.76it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC572645_seg19_mel.npy
# 扫描无效数据:  35%|███▍      | 64614/187052 [07:52<15:03, 135.49it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC732164_seg142_mel.npy
# 扫描无效数据:  37%|███▋      | 68410/187052 [08:20<14:50, 133.29it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC571221_seg19_mel.npy
# 扫描无效数据:  40%|████      | 74956/187052 [09:11<13:29, 138.50it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC392790_seg7_mel.npy
# 扫描无效数据:  43%|████▎     | 79742/187052 [09:49<14:00, 127.65it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC680315_seg17_mel.npy
# 扫描无效数据:  53%|█████▎    | 99248/187052 [12:18<10:44, 136.27it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC782924_seg59_mel.npy
# 扫描无效数据:  81%|████████  | 151113/187052 [18:58<04:49, 124.10it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591233_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591233_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591233_seg6_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591233_seg7_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591233_seg8_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg4_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg5_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg7_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg8_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591238_seg9_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591245_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591245_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591245_seg6_mel.npy
# 扫描无效数据:  81%|████████  | 151140/187052 [18:58<04:43, 126.77it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591245_seg7_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591245_seg8_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591245_seg11_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg6_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg7_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg10_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg11_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg14_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg15_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg18_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591250_seg19_mel.npy
# 扫描无效数据:  81%|████████  | 151168/187052 [18:58<04:38, 128.68it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591254_seg1_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591254_seg5_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591254_seg10_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg4_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg7_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg8_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg9_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591256_seg10_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591263_seg2_mel.npy
# 扫描无效数据:  81%|████████  | 151210/187052 [18:59<04:29, 132.98it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591263_seg5_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591263_seg6_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591263_seg9_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg6_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg7_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg10_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg11_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg12_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg13_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg16_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg17_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg18_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg19_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591272_seg20_mel.npy
# 扫描无效数据:  81%|████████  | 151238/187052 [18:59<04:26, 134.57it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg2_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg3_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg4_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg5_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg8_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg9_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg10_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg11_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC591289_seg12_mel.npy
# 扫描无效数据:  83%|████████▎ | 154382/187052 [19:22<04:29, 121.33it/s]
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC862345_seg27_mel.npy
# ❌ 发现 NaN/Inf: E:/AMR/DA/Projekt/data/Audio_spec_mel_512_256\XC862345_seg28_mel.npy
# 扫描无效数据: 100%|██████████| 187052/187052 [23:29<00:00, 132.73it/s]
# ✅ 黑名单已更新，共 72 个无效文件
#
# ✅ 已过滤无效数据，生成 E:/AMR/DA/Projekt/data/data_list/0408/all_data_meta_clean.csv（保留 186980 条数据）

# %% [markdown]
# # 修改标签

# %% [markdown]
# # ------------------------------------------------------------
# # 在此之前的代码一般只用执行一次

# %% [markdown]
# # Bird Target filter -> all_data_meta_allTypes.csv

# %%
import pandas as pd
import os
# 📌 文件路径
input_csv_path = f"{root_data_path}/all_data_meta_clean.csv"  # 经过 NaN/Inf 过滤和标签修正的文件
output_csv_path = f"{root_data_path}/all_data_meta_allTypes.csv"  # 目标鸟类数据

selected_birds = [
    "Black-headed Gull",
    "Canada Goose",
    "Carrion Crow",
    "Common Blackbird",
    "Common Chaffinch",
    "Common Kingfisher",
    "Common Redstart",
    "Dunnock",
    "Eurasian Blackcap",
    "Eurasian Blue Tit",
    "Eurasian Bullfinch",
    "Eurasian Coot",
    "Eurasian Golden Oriole",
    "Eurasian Jay",
    "Eurasian Nuthatch",
    "Eurasian Siskin",
    "Eurasian Treecreeper",
    "Eurasian Wren",
    "European Goldfinch",
    "European Robin",
    "Goldcrest",
    "Great Spotted Woodpecker",
    "Great Tit",
    "Hawfinch",
    "Hooded Crow",
    "Long-tailed Tit",
    "Mallard",
    "Marsh Tit",
    "Redwing",
    "Rook",
    "Short-toed Treecreeper",
    "Stock Dove",
    "Background Noise",
]

# 🎯 vocalization 过滤条件（根据你的实际需求修改）
selected_vocalization = ["Call", "Song", "Alarm call", "Flight call", "Begging call", "none"]  # 假设你只想保留 vocalization 为 'call' 或 'song' 的样本

# 读取数据
df = pd.read_csv(input_csv_path)
print(f"📊 过滤前数据: {len(df)} 条")

# 只保留目标鸟类
df_filtered = df[df["bird_name"].isin(selected_birds)]

# 只保留符合 vocalization 条件的数据
df_filtered = df_filtered[df_filtered["vocalization"].isin(selected_vocalization)]

# 保存筛选后的数据
df_filtered.to_csv(output_csv_path, index=False, encoding="utf-8")

print(f"✅ 目标鸟类和 vocalization 筛选完成，生成 {output_csv_path}（保留 {len(df_filtered)} 条数据）")
# Out:
# 📊 过滤前数据: 186980 条
# ✅ 目标鸟类和 vocalization 筛选完成，生成 E:/AMR/DA/Projekt/data/data_list/0408/all_data_meta_allTypes.csv（保留 186980 条数据）

# %% [markdown]
# # 通过birdnet调整label

# %% [markdown]
# # split train and valid

# %%
import os
import pandas as pd
from sklearn.model_selection import train_test_split

# 📌 文件路径
data_csv_path = f"{root_data_path}/all_data_meta_allTypes.csv"
train_csv_path = f"{root_data_path}/train_list.csv"
test_csv_path = f"{root_data_path}/valid_list.csv"

# 读取数据
df = pd.read_csv(data_csv_path)
print(f"📊 原始数据: {len(df)} 条")

# ✅ **定义音频编号解析函数**
def get_audio_id(number, bird_name):
    if bird_name == "Background Noise":
        return number
    return number.split("_")[0] if "_" in number else number

# 计算 `audio_id`
df["audio_id"] = df.apply(lambda row: get_audio_id(row["number"], row["bird_name"]), axis=1)

# 🚀 拆分为普通样本和负样本
neg_samples = df[df["bird_name"] == "Background Noise"].copy()
pos_samples = df[df["bird_name"] != "Background Noise"].copy()

# ✅ 按 audio_id 进行训练/测试划分（20% 测试集）
unique_audio_ids = pos_samples["audio_id"].unique()
train_audio_ids, test_audio_ids = train_test_split(unique_audio_ids, test_size=0.2, random_state=2024, shuffle=True)

train_df = pos_samples[pos_samples["audio_id"].isin(train_audio_ids)]
test_df = pos_samples[pos_samples["audio_id"].isin(test_audio_ids)]

# ✅ 限制测试集每类不超过 500 个样本，剩下的回流到训练集（排除碎片泄露）
test_limited_df = []
train_remainder_df = []
test_audio_ids_set = set(test_df["audio_id"])

for bird_name in test_df["bird_name"].unique():
    class_samples = test_df[test_df["bird_name"] == bird_name]

    if len(class_samples) > 500:
        test_limited = class_samples.sample(n=500, random_state=2024)
        remainder = class_samples.drop(test_limited.index)

        # ❗ 移除与 test_limited 相同 audio_id 的碎片，避免回流污染
        remainder = remainder[~remainder["audio_id"].isin(test_limited["audio_id"])]
        train_remainder = remainder
    else:
        test_limited = class_samples
        train_remainder = pd.DataFrame()

    test_limited_df.append(test_limited)
    train_remainder_df.append(train_remainder)

# 合并测试集 & 安全回流训练集
test_df = pd.concat(test_limited_df, ignore_index=True)
train_df = pd.concat([train_df] + train_remainder_df, ignore_index=True)

# ✅ 背景噪声划分
neg_audio_ids = neg_samples["audio_id"].unique()
print("\n🔍 负样本 `audio_id` 统计：")
print(pd.Series(neg_audio_ids).value_counts())

if len(neg_audio_ids) >= 2:
    train_neg_ids, test_neg_ids = train_test_split(neg_audio_ids, test_size=0.2, random_state=2024, shuffle=True)
    train_neg_df = neg_samples[neg_samples["audio_id"].isin(train_neg_ids)]
    test_neg_df = neg_samples[neg_samples["audio_id"].isin(test_neg_ids)]
else:
    print(f"⚠️ 负样本数量不足 ({len(neg_audio_ids)} 个)，全部放入训练集！")
    train_neg_df = neg_samples
    test_neg_df = pd.DataFrame(columns=df.columns)

# ✅ 合并训练 & 测试集
train_df = pd.concat([train_df, train_neg_df], ignore_index=True)
test_df = pd.concat([test_df, test_neg_df], ignore_index=True)

# ✅ 删除辅助列 audio_id
train_df.drop(columns=["audio_id"], inplace=True)
test_df.drop(columns=["audio_id"], inplace=True)

# ✅ 保存 CSV 文件
os.makedirs(os.path.dirname(train_csv_path), exist_ok=True)
train_df.to_csv(train_csv_path, index=False, encoding="utf-8")
test_df.to_csv(test_csv_path, index=False, encoding="utf-8")

print(f"✅ 训练集已保存至: {train_csv_path}, 样本数: {len(train_df)}")
print(f"✅ 测试集已保存至: {test_csv_path}, 样本数: {len(test_df)}")

# %% [markdown]
# # train and valid distribution

# %%
import pandas as pd
train_df = pd.read_csv("E:/AMR/DA/Projekt/data/train_list_for_zoom006_0315.csv")
valid_df = pd.read_csv("E:/AMR/DA/Projekt/data/valid_list_for_zoom006_0315.csv")

print("训练集类别分布:")
print(train_df["bird_name"].value_counts())

print("\n测试集类别分布:")
print(valid_df["bird_name"].value_counts())

train_df_refine = pd.read_csv("E:/AMR/DA/Projekt/data/train_list_for_zoom006_100_nofreefiled_refine_th12.csv")
valid_df_refine = pd.read_csv("E:/AMR/DA/Projekt/data/valid_list_for_zoom006_100_nofreefiled_refine_th12.csv")

print("训练集类别分布refine:")
print(train_df_refine["bird_name"].value_counts())
print("\n测试集类别分布refine:")
print(valid_df_refine["bird_name"].value_counts())
